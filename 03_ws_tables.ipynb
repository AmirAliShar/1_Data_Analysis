# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://en.wikipedia.org/wiki/World_population'

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all the tables on the webpage
tables = soup.find_all('table')

dataframes = []  # List to store all dataframes

# For each table, create a DataFrame and append it to the list
for i, table in enumerate(tables):
    # The [1:] is to skip the header row
    rows = table.find_all('tr')[1:]
    data = []
    for row in rows:
        cols = row.find_all('td')
        cols = [col.text.strip() for col in cols]
        data.append(cols)
    df = pd.DataFrame(data)
    dataframes.append(df)

# Now dataframes[0], dataframes[1], etc. each contain a different table from the page
dataframes[5].tail()
# Out:
#                                                     0            1      2  \
# 8                                                   8   Bangladesh    131
# 9                                                   9       Russia    146
# 10                                                 10       Mexico    103
# 11                                                     World total  6,127
# 12  Notes:\n\n\n^ 2030 = Medium variant.\n\n^ Chin...         None   None
#
#         3      4
# 8     161    186
# 9     146    149
# 10    127    148
# 11  7,349  8,501
# 12   None   None

# %%
#using pandas
p=pd.read_html('https://en.wikipedia.org/wiki/Tesla,_Inc.')[0]
p.head()
# Out:
#                                                    0  \
# 0                                                NaN
# 1  Gigafactory Texas, Tesla's headquarters, in Au...
# 2                                           Formerly
# 3                                       Company type
# 4                                          Traded as
#
#                                                    1
# 0                                                NaN
# 1  Gigafactory Texas, Tesla's headquarters, in Au...
# 2                     Tesla Motors, Inc. (2003–2017)
# 3                                             Public
# 4  Nasdaq: TSLANasdaq-100 componentS&P 100 compon...

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

url='https://www.ambitionbox.com/list-of-companies?page=1'

# %%
# If error code 403 then use it
head={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"}
res=requests.get('https://en.wikipedia.org/wiki/Tesla,_Inc.',headers=head).text

# %%
soup=BeautifulSoup(res,"lxml")

# %%
#Show the structure
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Tesla, Inc. - Wikipedia
#   </title>
#   <script>
# ...

# %%
#show the all h1 tags only text
soup.find_all("h1")[0].text #Gave the only text
# Out:
# 'Tesla, Inc.'

# %%
for i in soup.find_all("h2"):
    print(i.text.strip())# strip is used for remove the only space
# Out:
# Contents
# History
# Automotive products and services
# Energy products
# Business strategy
# Technology
# Facilities
# Partners
# Lawsuits and controversies
# Criticism
# Vehicle product issues
# Vehicle sales
# Finances
# Corporate affairs
# See also
# Notes
# References
# Sources
# Further reading
# External links

# %%
for i in soup.find_all("h3"):
    print(i.text)
# Out:
# Founding (2003–2004)
# Roadster (2005–2009)
# IPO, Model S, and Model X (2010–2015)
# SolarCity and Model 3 (2016–2018)
# Global expansion and Model Y (2019–present)
# Available products
# Announced products
# Discontinued Tesla Roadster
# Connectivity services
# Vehicle servicing
#  Charging services
# Insurance services
#  Batteries
# Software
# Motors
#  North American Charging Standard
# Autopilot and Full Self-Driving
# Robotics
# Glass
# North America
# Europe
# Asia
# Panasonic
# Other current partners
# Former partners
# Sexual harassment
# Labor disputes
# Fraud allegations
# Tesla US dealership disputes
# Intellectual property
# Misappropriation
# Environmental violations
# Property damage
# Racism
# COVID-19 pandemic
# Right to repair
# Data privacy
# Short sellers
# Tesla's mission
# Giga New York audit
# Delays
# Recalls
# Fires
# Autopilot crashes
# Software hacking
# Phantom braking
# Driving range performance
# Production and sales by quarter
# ...

# %%
for i in soup.find_all("p"):
    print(i.text.strip())
# Out:
# Tesla, Inc. (/ˈtɛslə/ TESS-lə or /ˈtɛzlə/ TEZ-lə[a]) is an American multinational automotive and clean energy company. Headquartered in Austin, Texas, it designs, manufactures and sells battery electric vehicles (BEVs), stationary battery energy storage devices from home to grid-scale, solar panels and solar shingles, and related products and services.
# ...
